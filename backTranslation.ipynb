# %%
# https://pypi.org/project/BackTranslation/
# https://pypi.org/project/btranslation/

! pip install btranslation
# Out:
# Collecting btranslation
#   Downloading btranslation-1.0.1-py3-none-any.whl (3.6 kB)
# Requirement already satisfied: googletrans in /Users/aklabjan/miniconda3/lib/python3.10/site-packages (from btranslation) (4.0.0rc1)
# Requirement already satisfied: numpy in /Users/aklabjan/miniconda3/lib/python3.10/site-packages (from btranslation) (1.24.2)
# Requirement already satisfied: pandas in /Users/aklabjan/miniconda3/lib/python3.10/site-packages (from btranslation) (1.5.3)
# Requirement already satisfied: httpx==0.13.3 in /Users/aklabjan/miniconda3/lib/python3.10/site-packages (from googletrans->btranslation) (0.13.3)
# Requirement already satisfied: certifi in /Users/aklabjan/miniconda3/lib/python3.10/site-packages (from httpx==0.13.3->googletrans->btranslation) (2022.12.7)
# Requirement already satisfied: hstspreload in /Users/aklabjan/miniconda3/lib/python3.10/site-packages (from httpx==0.13.3->googletrans->btranslation) (2023.1.1)
# Requirement already satisfied: sniffio in /Users/aklabjan/miniconda3/lib/python3.10/site-packages (from httpx==0.13.3->googletrans->btranslation) (1.3.0)
# Requirement already satisfied: chardet==3.* in /Users/aklabjan/miniconda3/lib/python3.10/site-packages (from httpx==0.13.3->googletrans->btranslation) (3.0.4)
# Requirement already satisfied: idna==2.* in /Users/aklabjan/miniconda3/lib/python3.10/site-packages (from httpx==0.13.3->googletrans->btranslation) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in /Users/aklabjan/miniconda3/lib/python3.10/site-packages (from httpx==0.13.3->googletrans->btranslation) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in /Users/aklabjan/miniconda3/lib/python3.10/site-packages (from httpx==0.13.3->googletrans->btranslation) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in /Users/aklabjan/miniconda3/lib/python3.10/site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans->btranslation) (0.9.0)
# Requirement already satisfied: h2==3.* in /Users/aklabjan/miniconda3/lib/python3.10/site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans->btranslation) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /Users/aklabjan/miniconda3/lib/python3.10/site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans->btranslation) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /Users/aklabjan/miniconda3/lib/python3.10/site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans->btranslation) (3.0.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/aklabjan/miniconda3/lib/python3.10/site-packages (from pandas->btranslation) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/aklabjan/miniconda3/lib/python3.10/site-packages (from pandas->btranslation) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /Users/aklabjan/miniconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->btranslation) (1.16.0)
# Installing collected packages: btranslation
# Successfully installed btranslation-1.0.1

# %%
import btranslation
import pandas as pd
import os

# %%
import btranslation
import pandas as pd
import os

def read_tsv(group, delimiter='\t'):
    """
    Reads a .tsv file and returns a Pandas DataFrame.

    Parameters:
    - file_path (str): Path to the .tsv file.
    - delimiter (str): Delimiter used in the file (default is '\t' for tab-separated values).

    Returns:
    - pd.DataFrame: The DataFrame containing the data from the .tsv file.
    """
    try:
        file_path = os.path.join('data',group,'train.tsv')
        # Read the .tsv file into a DataFrame
        dataframe = pd.read_csv(file_path, delimiter=delimiter, header=None, names=['text', 'emotion', 'labeler'])
        return dataframe
    except Exception as e:
        print(f"Error reading the .tsv file: {e}")
        return None
    
def createFile(group):
    original_df = read_tsv(group)
    btrans = btranslation.back_translation(original_df[:100]['text'].values)
    translated_df = pd.concat([btrans['Back Translated'], original_df['emotion'], original_df['labeler']], axis=1)
    translated_df = translated_df.rename(columns={'Back Translated': 'text'})
    combined_df = original_df.append(translated_df, ignore_index=True)
    combined_df = combined_df.drop_duplicates()
    path = os.path.join('data',group,'augmented_train.tsv')
    combined_df.to_csv(path, sep='\t', index=False)
createFile('original')
# Out:
# /var/folders/y9/5tj9lw0j1934b6b3lt2zw7jr0000gp/T/ipykernel_30843/2611177169.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df = original_df.append(translated_df, ignore_index=True)

# %%
from BackTranslation import BackTranslation
trans = BackTranslation()
# Out:
# {'russian': 'ru'}

# %%
df['text'].values.tolist()
# Out:
# ["My favourite food is anything I didn't have to cook myself.",
#  'Now if he does off himself, everyone will think hes having a laugh screwing with people instead of actually dead',
#  'WHY THE FUCK IS BAYLESS ISOING',
#  'To make her feel threatened',
#  'Dirty Southern Wankers',
#  "OmG pEyToN iSn'T gOoD eNoUgH tO hElP uS iN tHe PlAyOfFs! Dumbass Broncos fans circa December 2015.",
#  'Yes I heard abt the f bombs! That has to be why. Thanks for your reply:) until then hubby and I will anxiously wait 😝',
#  'We need more boards and to create a bit more space for [NAME]. Then we’ll be good.',
#  'Damn youtube and outrage drama is super lucrative for reddit',
#  'It might be linked to the trust factor of your friend.']

# %%
count = 0
output = []
for line in df['text'].values.tolist():
    result = trans.translate(line, src='en', tmp = 'ru',sleeping = 10)
    output.append(result.result_text)
    if count % 100 == 0:
        print(count)
    count += 1
# Out:
# 0
# 100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 4
#       2 output = []
#       3 for line in df['text'].values.tolist():
# ----> 4     result = trans.translate(line, src='en', tmp = 'ru',sleeping = 10)
#       5     output.append(result.result_text)
#       6     if count % 100 == 0:
#
# File ~/miniconda3/lib/python3.10/site-packages/BackTranslation/translation.py:68, in BackTranslation.translate(self, text, src, tmp, sleeping)
#      66 mid_text = self.translator.translate(text, src=src, dest=tmp)
#      67 tran_text = mid_text.text
# ---> 68 time.sleep(sleeping)  # Sleep between translation
#      69 result_text = self.translator.translate(tran_text, src=tmp, dest=src)
#      70 back_text = result_text.text
#
# KeyboardInterrupt:

# %%
len(output)
# Out:
# 163

# %%
folder = 'ekman'
df = read_tsv(folder)
chunk_size = 50
chunks = [df[i:i + chunk_size] for i in range(0, len(df), chunk_size)]

count = 0
for chunk in chunks:
    output = []
    for line in chunk['text'].values.tolist():
        result = trans.translate(line, src='en', tmp = 'ru',sleeping = 10)
        output.append(result.result_text)
    translated_df = pd.DataFrame({
    'text': output,
    'emotion': chunk['emotion'],
    'labeler': chunk['labeler']
    })
    # Specify the path to the existing .tsv file
    existing_file_path = os.path.join('data',folder','augmented_train.tsv')

    # Append the new_data DataFrame to the existing .tsv file
    translated_df.to_csv(existing_file_path, sep='\t', mode='a', header=False, index=False)
    print(f'completed {count}') 
    count += 1

# %%
df = read_tsv('group')[1013:]
chunk_size = 50
chunks = [df[i:i + chunk_size] for i in range(0, len(df), chunk_size)]

count = 0
for chunk in chunks:
    output = []
    for line in chunk['text'].values.tolist():
        result = trans.translate(line, src='en', tmp = 'ru',sleeping = 1)
        output.append(result.result_text)
    translated_df = pd.DataFrame({
    'text': output,
    'emotion': chunk['emotion'],
    'labeler': chunk['labeler']
    })
    # Specify the path to the existing .tsv file
    existing_file_path = os.path.join('data','group','augmented_train.tsv')

    # Append the new_data DataFrame to the existing .tsv file
    translated_df.to_csv(existing_file_path, sep='\t', mode='a', header=False, index=False)
    print(f'completed {count}') 
    count += 1
# Out:
# completed 0
# completed 1
# completed 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 9
#       7 output = []
#       8 for line in chunk['text'].values.tolist():
# ----> 9     result = trans.translate(line, src='en', tmp = 'ru',sleeping = 1)
#      10     output.append(result.result_text)
#      11 translated_df = pd.DataFrame({
#      12 'text': output,
#      13 'emotion': chunk['emotion'],
#      14 'labeler': chunk['labeler']
#      15 })
#
# File ~/miniconda3/lib/python3.10/site-packages/BackTranslation/translation.py:68, in BackTranslation.translate(self, text, src, tmp, sleeping)
#      66 mid_text = self.translator.translate(text, src=src, dest=tmp)
#      67 tran_text = mid_text.text
# ---> 68 time.sleep(sleeping)  # Sleep between translation
#      69 result_text = self.translator.translate(tran_text, src=tmp, dest=src)
#      70 back_text = result_text.text
#
# KeyboardInterrupt:

# %%
def read_tsv(group, delimiter='\t'):
    """
    Reads a .tsv file and returns a Pandas DataFrame.

    Parameters:
    - file_path (str): Path to the .tsv file.
    - delimiter (str): Delimiter used in the file (default is '\t' for tab-separated values).

    Returns:
    - pd.DataFrame: The DataFrame containing the data from the .tsv file.
    """
    try:
        file_path = os.path.join('data',group,'train.tsv')
        # Read the .tsv file into a DataFrame
        dataframe = pd.read_csv(file_path, delimiter=delimiter, header=None, names=['text', 'emotion', 'labeler'])
        return dataframe
    except Exception as e:
        print(f"Error reading the .tsv file: {e}")
        return None

# %%
df = read_tsv('group')

# %%
df[:10]
# Out:
#                                                 Text Labels  Labeler
# 0  My favourite food is anything I didn't have to...     27  eebbqej
# 1  Now if he does off himself, everyone will thin...     27  ed00q6i
# 2                     WHY THE FUCK IS BAYLESS ISOING      2  eezlygj
# 3                        To make her feel threatened     14  ed7ypvh
# 4                             Dirty Southern Wankers      3  ed0bdzj
# 5  OmG pEyToN iSn'T gOoD eNoUgH tO hElP uS iN tHe...     26  edvnz26
# 6  Yes I heard abt the f bombs! That has to be wh...     15  ee3b6wu
# 7  We need more boards and to create a bit more s...   8,20  ef4qmod
# 8  Damn youtube and outrage drama is super lucrat...      0  ed8wbdn
# 9  It might be linked to the trust factor of your...     27  eczgv1o

# %%
btrans = btranslation.back_translation(df['Text'].values, language = 'ru')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 btrans = btranslation.back_translation(df['Text'].values, language = 'ru')
#
# File ~/miniconda3/lib/python3.10/site-packages/btranslation/__init__.py:43, in back_translation(text_list, language)
#      40 else:
#      41     rand_lang = language
# ---> 43 random_translation = translator.translate(text, dest = rand_lang).text
#      45 back_translation = translator.translate(random_translation, dest = detected_lang).text
#      47 if back_translation != text:
#
# File ~/miniconda3/lib/python3.10/site-packages/googletrans/client.py:194, in Translator.translate(self, text, dest, src)
#     191         raise ValueError('invalid destination language')
#     193 origin = text
# --> 194 data, response = self._translate(text, dest, src)
#     196 token_found = False
#     197 square_bracket_counts = [0, 0]
#
# File ~/miniconda3/lib/python3.10/site-packages/googletrans/client.py:120, in Translator._translate(self, text, dest, src)
#     109 data = {
#     110     'f.req': self._build_rpc_request(text, dest, src),
#     111 }
#     112 params = {
#     113     'rpcids': RPC_ID,
#     114     'bl': 'boq_translate-webserver_20201207.13_p0',
#    (...)
#     118     'rt': 'c',
#     119 }
# --> 120 r = self.client.post(url, params=params, data=data)
#     122 if r.status_code != 200 and self.raise_Exception:
#     123     raise Exception('Unexpected status code "{}" from {}'.format(
#     124         r.status_code, self.service_urls))
#
# File ~/miniconda3/lib/python3.10/site-packages/httpx/_client.py:824, in Client.post(self, url, data, files, json, params, headers, cookies, auth, allow_redirects, timeout)
#     810 def post(
#     811     self,
#     812     url: URLTypes,
#    (...)
#     822     timeout: typing.Union[TimeoutTypes, UnsetType] = UNSET,
#     823 ) -> Response:
# --> 824     return self.request(
#     825         "POST",
#     826         url,
#     827         data=data,
#     828         files=files,
#     829         json=json,
#     830         params=params,
#     831         headers=headers,
#     832         cookies=cookies,
#     833         auth=auth,
#     834         allow_redirects=allow_redirects,
#     835         timeout=timeout,
#     836     )
#
# File ~/miniconda3/lib/python3.10/site-packages/httpx/_client.py:600, in Client.request(self, method, url, data, files, json, params, headers, cookies, auth, allow_redirects, timeout)
#     575 def request(
#     576     self,
#     577     method: str,
#    (...)
#     588     timeout: typing.Union[TimeoutTypes, UnsetType] = UNSET,
#     589 ) -> Response:
#     590     request = self.build_request(
#     591         method=method,
#     592         url=url,
#    (...)
#     598         cookies=cookies,
#     599     )
# --> 600     return self.send(
#     601         request, auth=auth, allow_redirects=allow_redirects, timeout=timeout,
#     602     )
#
# File ~/miniconda3/lib/python3.10/site-packages/httpx/_client.py:620, in Client.send(self, request, stream, auth, allow_redirects, timeout)
#     616 timeout = self.timeout if isinstance(timeout, UnsetType) else Timeout(timeout)
#     618 auth = self.build_auth(request, auth)
# --> 620 response = self.send_handling_redirects(
#     621     request, auth=auth, timeout=timeout, allow_redirects=allow_redirects,
#     622 )
#     624 if not stream:
#     625     try:
#
# File ~/miniconda3/lib/python3.10/site-packages/httpx/_client.py:647, in Client.send_handling_redirects(self, request, auth, timeout, allow_redirects, history)
#     644 if len(history) > self.max_redirects:
#     645     raise TooManyRedirects()
# --> 647 response = self.send_handling_auth(
#     648     request, auth=auth, timeout=timeout, history=history
#     649 )
#     650 response.history = list(history)
#     652 if not response.is_redirect:
#
# File ~/miniconda3/lib/python3.10/site-packages/httpx/_client.py:684, in Client.send_handling_auth(self, request, history, auth, timeout)
#     682 request = next(auth_flow)
#     683 while True:
# --> 684     response = self.send_single_request(request, timeout)
#     685     if auth.requires_response_body:
#     686         response.read()
#
# File ~/miniconda3/lib/python3.10/site-packages/httpx/_client.py:714, in Client.send_single_request(self, request, timeout)
#     705 transport = self.transport_for_url(request.url)
#     707 try:
#     708     (
#     709         http_version,
#     710         status_code,
#     711         reason_phrase,
#     712         headers,
#     713         stream,
# --> 714     ) = transport.request(
#     715         request.method.encode(),
#     716         request.url.raw,
#     717         headers=request.headers.raw,
#     718         stream=request.stream,
#     719         timeout=timeout.as_dict(),
#     720     )
#     721 except HTTPError as exc:
#     722     # Add the original request to any HTTPError unless
#     723     # there'a already a request attached in the case of
#     724     # a ProxyError.
#     725     if exc._request is None:
#
# File ~/miniconda3/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:152, in SyncConnectionPool.request(self, method, url, headers, stream, timeout)
#     149         logger.trace("reuse connection=%r", connection)
#     151 try:
# --> 152     response = connection.request(
#     153         method, url, headers=headers, stream=stream, timeout=timeout
#     154     )
#     155 except NewConnectionRequired:
#     156     connection = None
#
# File ~/miniconda3/lib/python3.10/site-packages/httpcore/_sync/connection.py:78, in SyncHTTPConnection.request(self, method, url, headers, stream, timeout)
#      74 assert self.connection is not None
#      75 logger.trace(
#      76     "connection.request method=%r url=%r headers=%r", method, url, headers
#      77 )
# ---> 78 return self.connection.request(method, url, headers, stream, timeout)
#
# File ~/miniconda3/lib/python3.10/site-packages/httpcore/_sync/http2.py:118, in SyncHTTP2Connection.request(self, method, url, headers, stream, timeout)
#     116     self.streams[stream_id] = h2_stream
#     117     self.events[stream_id] = []
# --> 118     return h2_stream.request(method, url, headers, stream, timeout)
#     119 except Exception:
#     120     self.max_streams_semaphore.release()
#
# File ~/miniconda3/lib/python3.10/site-packages/httpcore/_sync/http2.py:292, in SyncHTTP2Stream.request(self, method, url, headers, stream, timeout)
#     289     self.send_body(stream, timeout)
#     291 # Receive the response.
# --> 292 status_code, headers = self.receive_response(timeout)
#     293 reason_phrase = get_reason_phrase(status_code)
#     294 stream = SyncByteStream(
#     295     iterator=self.body_iter(timeout), close_func=self._response_closed
#     296 )
#
# File ~/miniconda3/lib/python3.10/site-packages/httpcore/_sync/http2.py:344, in SyncHTTP2Stream.receive_response(self, timeout)
#     340 """
#     341 Read the response status and headers from the network.
#     342 """
#     343 while True:
# --> 344     event = self.connection.wait_for_event(self.stream_id, timeout)
#     345     if isinstance(event, h2.events.ResponseReceived):
#     346         break
#
# File ~/miniconda3/lib/python3.10/site-packages/httpcore/_sync/http2.py:197, in SyncHTTP2Connection.wait_for_event(self, stream_id, timeout)
#     195 with self.read_lock:
#     196     while not self.events[stream_id]:
# --> 197         self.receive_events(timeout)
#     198 return self.events[stream_id].pop(0)
#
# File ~/miniconda3/lib/python3.10/site-packages/httpcore/_sync/http2.py:204, in SyncHTTP2Connection.receive_events(self, timeout)
#     200 def receive_events(self, timeout: TimeoutDict) -> None:
#     201     """
#     202     Read some data from the network, and update the H2 state.
#     203     """
# --> 204     data = self.socket.read(self.READ_NUM_BYTES, timeout)
#     205     events = self.h2_state.receive_data(data)
#     206     for event in events:
#
# File ~/miniconda3/lib/python3.10/site-packages/httpcore/_backends/sync.py:62, in SyncSocketStream.read(self, n, timeout)
#      60 with map_exceptions(exc_map):
#      61     self.sock.settimeout(read_timeout)
# ---> 62     return self.sock.recv(n)
#
# File ~/miniconda3/lib/python3.10/ssl.py:1259, in SSLSocket.recv(self, buflen, flags)
#    1255     if flags != 0:
#    1256         raise ValueError(
#    1257             "non-zero flags not allowed in calls to recv() on %s" %
#    1258             self.__class__)
# -> 1259     return self.read(buflen)
#    1260 else:
#    1261     return super().recv(buflen, flags)
#
# File ~/miniconda3/lib/python3.10/ssl.py:1132, in SSLSocket.read(self, len, buffer)
#    1130         return self._sslobj.read(len, buffer)
#    1131     else:
# -> 1132         return self._sslobj.read(len)
#    1133 except SSLError as x:
#    1134     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
btrans
# Out:
#                                             Original  \
# 0  My favourite food is anything I didn't have to...
# 1  Now if he does off himself, everyone will thin...
# 2                     WHY THE FUCK IS BAYLESS ISOING
# 3                        To make her feel threatened
# 4                             Dirty Southern Wankers
# 5  OmG pEyToN iSn'T gOoD eNoUgH tO hElP uS iN tHe...
# 6  Yes I heard abt the f bombs! That has to be wh...
# 7  We need more boards and to create a bit more s...
# 8  Damn youtube and outrage drama is super lucrat...
# 9  It might be linked to the trust factor of your...
#
#                                      Back Translated Random Language
# 0   My favorite food is that I did not need to cook.              ru
# 1  Now, if he comes from himself, everyone will t...              ru
# 2                                       Why the hell              ru
# 3                         So that she feels a threat              ru
# 4                             Dirty southern Katists              ru
# 5  Omg Peyton is not good enough to help us in th...              ru
# 6  Yes, I heard about bombs! It should be why. Th...              ru
# 7  We need more boards and create a little more s...              ru
# 8  Damn YouTube and the drama of indignation is v...              ru
# 9  This may be due to the factor of your friend's...              ru

# %%
df
# Out:
#                                                     text emotion  labeler
# 0      My favourite food is anything I didn't have to...      27  eebbqej
# 1      Now if he does off himself, everyone will thin...      27  ed00q6i
# 2                         WHY THE FUCK IS BAYLESS ISOING       2  eezlygj
# 3                            To make her feel threatened      14  ed7ypvh
# 4                                 Dirty Southern Wankers       3  ed0bdzj
# ...                                                  ...     ...      ...
# 43405  Added you mate well I’ve just got the bow and ...      18  edsb738
# 43406  Always thought that was funny but is it a refe...       6  ee7fdou
# 43407  What are you talking about? Anything bad that ...       3  efgbhks
# 43408            More like a baptism, with sexy results!      13  ed1naf8
# 43409                                    Enjoy the ride!      17  eecwmbq
#
# [43410 rows x 3 columns]

# %%
len(df)
# Out:
# 43410

# %%
df2 = df[:10]
df2
# Out:
#                                                 text emotion  labeler
# 0  My favourite food is anything I didn't have to...      27  eebbqej
# 1  Now if he does off himself, everyone will thin...      27  ed00q6i
# 2                     WHY THE FUCK IS BAYLESS ISOING       2  eezlygj
# 3                        To make her feel threatened      14  ed7ypvh
# 4                             Dirty Southern Wankers       3  ed0bdzj
# 5  OmG pEyToN iSn'T gOoD eNoUgH tO hElP uS iN tHe...      26  edvnz26
# 6  Yes I heard abt the f bombs! That has to be wh...      15  ee3b6wu
# 7  We need more boards and to create a bit more s...    8,20  ef4qmod
# 8  Damn youtube and outrage drama is super lucrat...       0  ed8wbdn
# 9  It might be linked to the trust factor of your...      27  eczgv1o

# %%
new_df = pd.concat([btrans['Back Translated'], df2['emotion'], df2['labeler']], axis=1)
new_df = new_df.rename(columns={'Back Translated': 'text'})
new_df
# Out:
#                                                 text emotion  labeler
# 0   My favorite food is that I did not need to cook.      27  eebbqej
# 1  Now, if he comes from himself, everyone will t...      27  ed00q6i
# 2                                       Why the hell       2  eezlygj
# 3                         So that she feels a threat      14  ed7ypvh
# 4                             Dirty southern Katists       3  ed0bdzj
# 5  Omg Peyton is not good enough to help us in th...      26  edvnz26
# 6  Yes, I heard about bombs! It should be why. Th...      15  ee3b6wu
# 7  We need more boards and create a little more s...    8,20  ef4qmod
# 8  Damn YouTube and the drama of indignation is v...       0  ed8wbdn
# 9  This may be due to the factor of your friend's...      27  eczgv1o

# %%
df_combined = df2.append(new_df, ignore_index=True)
df_combined
# Out:
# /var/folders/y9/5tj9lw0j1934b6b3lt2zw7jr0000gp/T/ipykernel_28350/1483174218.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_combined = df2.append(new_df, ignore_index=True)
#                                                  text emotion  labeler
# 0   My favourite food is anything I didn't have to...      27  eebbqej
# 1   Now if he does off himself, everyone will thin...      27  ed00q6i
# 2                      WHY THE FUCK IS BAYLESS ISOING       2  eezlygj
# 3                         To make her feel threatened      14  ed7ypvh
# 4                              Dirty Southern Wankers       3  ed0bdzj
# 5   OmG pEyToN iSn'T gOoD eNoUgH tO hElP uS iN tHe...      26  edvnz26
# 6   Yes I heard abt the f bombs! That has to be wh...      15  ee3b6wu
# 7   We need more boards and to create a bit more s...    8,20  ef4qmod
# 8   Damn youtube and outrage drama is super lucrat...       0  ed8wbdn
# 9   It might be linked to the trust factor of your...      27  eczgv1o
# 10   My favorite food is that I did not need to cook.      27  eebbqej
# 11  Now, if he comes from himself, everyone will t...      27  ed00q6i
# 12                                       Why the hell       2  eezlygj
# 13                         So that she feels a threat      14  ed7ypvh
# 14                             Dirty southern Katists       3  ed0bdzj
# 15  Omg Peyton is not good enough to help us in th...      26  edvnz26
# 16  Yes, I heard about bombs! It should be why. Th...      15  ee3b6wu
# 17  We need more boards and create a little more s...    8,20  ef4qmod
# 18  Damn YouTube and the drama of indignation is v...       0  ed8wbdn
# 19  This may be due to the factor of your friend's...      27  eczgv1o
